# %% [markdown]
# <a href="https://colab.research.google.com/github/shasi4069/davis_training/blob/main/Module_in_python/Calculation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#calculation1.py
import NumericCalculation
m=10
n=20
print("sum of",m,"and",n,"is:",NumericCalculation.calculateSum(m,n))
print("product of",m,"and",n,"is:",NumericCalculation.calculateMul(m,n))
