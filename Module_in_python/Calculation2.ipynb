# %% [markdown]
# <a href="https://colab.research.google.com/github/shasi4069/davis_training/blob/main/Module_in_python/Calculation2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# calculation2.py
from NumericCalculation import *
m=10
n=20
print("sum of",m,"and",n,"is:",calculateSum(m,n))
print("sum of",m,"and",n,"is:",calculateMul(m,n))
