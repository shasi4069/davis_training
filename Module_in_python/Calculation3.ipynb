# %% [markdown]
# <a href="https://colab.research.google.com/github/shasi4069/davis_training/blob/main/Module_in_python/Calculation3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#calculation3.py
from NumericCalculation import addnumbers
m=10
n=30
print("sum of",m,"and",n,"is:",calculateSum(m,n))
print("sum of",m,"and",n,"is:",calculateMul(m,n))
