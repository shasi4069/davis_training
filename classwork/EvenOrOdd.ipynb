# %% [markdown]
# <a href="https://colab.research.google.com/github/shasi4069/davis_training/blob/main/classwork/EvenOrOdd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_even_odd(num):
  if(num % 2 == 0):
    print(f"{num} is even")
  else:
    print(f"{num} is odd")

num = int(input("Enter the Number: "))
check_even_odd(num)
