# %% [markdown]
# <a href="https://colab.research.google.com/github/shasi4069/davis_training/blob/main/classwork/GreatestDigit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter the number: "))
max = 0
while(num > 0):
  digit = num % 10
  if(digit > max):
    max = digit
  num = num // 10
print(f"Greatest Digit : {max}")
