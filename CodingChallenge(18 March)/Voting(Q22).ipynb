# %% [markdown]
# <a href="https://colab.research.google.com/github/shasi4069/davis_training/blob/main/CodingChallenge(18%20March)/Voting(Q22).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Voting Eligible Criteria
age = int(input("Enter Age: "))
if age >= 18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# Enter Age: 13
# You are not eligible to vote
