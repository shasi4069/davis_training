# %% [markdown]
# <a href="https://colab.research.google.com/github/shasi4069/davis_training/blob/main/CodingChallenge(18%20March)/SI(Q10).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SI using function

def si(p,r,t):
    return (p*r*t)/100

print("Simple Interest:", si(float(input("P: ")), float(input("R: ")), float(input("T: "))))
# Out:
# P: 300
# R: 20
# T: 23
# Simple Interest: 1380.0
