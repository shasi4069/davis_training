# %% [markdown]
# <a href="https://colab.research.google.com/github/shasi4069/davis_training/blob/main/CodingChallenge(18%20March)/SI(Q25).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# One-line SI

p = float(input("P: "))
r = float(input("R: "))
t = float(input("T: "))
print("SI:", (p*r*t)/100)
# Out:
# P: 4500
# R: 5
# T: 5
# SI: 1125.0
