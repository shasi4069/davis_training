# %% [markdown]
# <a href="https://colab.research.google.com/github/shasi4069/davis_training/blob/main/CodingChallenge(18%20March)/Q42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to check voting eligibility

# Taking input
age = int(input("Enter age: "))

# Checking condition
if age >= 18:
    print("Eligible to vote")
else:
    print("Not Eligible")
