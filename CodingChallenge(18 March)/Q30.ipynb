# %% [markdown]
# <a href="https://colab.research.google.com/github/shasi4069/davis_training/blob/main/CodingChallenge(18%20March)/Q30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SI using class

class SI:
    def calc(self,p,r,t):
        return (p*r*t)/100

print("SI:", SI().calc(float(input()),float(input()),float(input())))
