# %% [markdown]
# <a href="https://colab.research.google.com/github/shasi4069/davis_training/blob/main/CodingChallenge(18%20March)/SI(Using_Lambda_Q15).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#SI using lambda

p = float(input("P: "))
r = float(input("R: "))
t = float(input("T: "))

si = lambda p,r,t: (p*r*t)/100
print("SI:", si(p,r,t))
# Out:
# P: 1000
# R: 5
# T: 10
# SI: 500.0
