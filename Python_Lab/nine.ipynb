# %% [markdown]
# <a href="https://colab.research.google.com/github/shasi4069/davis_training/blob/main/Python_Lab/nine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rows = int(input("Enter number of rows: "))

for i in range(1, rows+1):
    if i % 2 == 0:
        print("* " * i)
    else:
        print("# " * i)
# Out:
# Enter number of rows: 5
# #
# * *
# # # #
# * * * *
# # # # # #
