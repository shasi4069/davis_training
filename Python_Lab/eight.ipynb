# %% [markdown]
# <a href="https://colab.research.google.com/github/shasi4069/davis_training/blob/main/Python_Lab/eight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_palindrome(value):
    value = str(value)

    if value == value[::-1]:
        return True
    return False

data = input("Enter value: ")

if is_palindrome(data):
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter value: 123
# Not Palindrome
