# %% [markdown]
# <a href="https://colab.research.google.com/github/shasi4069/davis_training/blob/main/EvenOdd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# function to check even or odd
def checkEvenOdd(num):
    if num % 2 == 0:
        print("Even Number")
    else:
        print("Odd Number")

# main program
number = int(input("Enter a number: "))
checkEvenOdd(number)
# Out:
# Enter a number: 6
# Even Number
